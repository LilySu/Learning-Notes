# %%
# !pip install scattertext
# !pip install flashtext
# !pip install spacy
# Out:
# Collecting scattertext
#   Downloading https://files.pythonhosted.org/packages/e0/6a/d2b2af772934a946cbebb47cb068b4631ed437a264d9cfc7ef5761f95e00/scattertext-0.0.2.56-py3-none-any.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 4.1MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.4.1)
# Collecting mock
#   Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.25.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.12.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.10.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from scattertext) (0.22.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scattertext) (1.17.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->scattertext) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->scattertext) (2018.9)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels->scattertext) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->scattertext) (0.14.1)
# Installing collected packages: mock, scattertext
# Successfully installed mock-3.0.5 scattertext-0.0.2.56
# Collecting flashtext
#   Downloading https://files.pythonhosted.org/packages/81/d8/2cd0656eae456d615c2f1efbcae8dfca2cb871a31f34ba8925aba47d5e09/flashtext-2.7.tar.gz
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9298 sha256=a03e5e7de607ac0e05bc97abba28d04a0f82be69d8032cbebaf293b3c8e4a8b7
#   Stored in directory: /root/.cache/pip/wheels/37/db/d7/fe74f7cb8e5c3afed90fe6f4967c933a6f13d81ab6b3d3128c
# Successfully built flashtext
# Installing collected packages: flashtext
# Successfully installed flashtext-2.7
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.1.9)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.21.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.9.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.17.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.28.1)

# %%
#breaks reviews up into individual words, tallies up word occurrences and extracts phrases where word appears.
#spacy and scattertext are not used because the results are decent without it and for companies with few reviews, compute time is instant.

from collections import Counter
from flashtext import KeywordProcessor
import scattertext as st
import json
import warnings
import pandas as pd
import numpy as np
from lxml import html
from requests import Session
from concurrent.futures import ThreadPoolExecutor as Executor
import requests
import re
import spacy
nlp = spacy.load("en_core_web_sm")
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.max_colwidth', 1000)
base_url = "https://www.yelp.com/biz/" 
api_url = "/review_feed?sort_by=date_desc&start="
bid = 'lJAGnYzku5zSaLnQ_T6_GQ'


class Scraper():
    def __init__(self):
        self.data = pd.DataFrame()

    def get_data(self, n, bid=bid):
        with Session() as s:
            with s.get(base_url+bid+api_url+str(n*20)) as resp: #makes an http get request to given url and returns response as json
                r = json.loads(resp.content) #converts json response into a dictionary
                _html = html.fromstring(r['review_list']) #loads from dictionary

                dates = _html.xpath("//div[@class='review-content']/descendant::span[@class='rating-qualifier']/text()")
                reviews = [el.text for el in _html.xpath("//div[@class='review-content']/p")]
                ratings = _html.xpath("//div[@class='review-content']/descendant::div[@class='biz-rating__stars']/div/@title")

                df = pd.DataFrame([dates, reviews, ratings]).T

                self.data = pd.concat([self.data,df])

    def scrape(self): #makes it faster
        # multithreaded looping
        with Executor(max_workers=40) as e:
            list(e.map(self.get_data, range(10)))

s = Scraper()
s.scrape()
df = s.data
df = df.dropna()

# %%
def customtokensize(text):
    return re.findall("[\w']+", str(text))

df['tokenized_text'] = df[1].apply(customtokensize)
stopwords = ['and','was','were','had','check-in','=','= =','u','want', 'u want', 'cuz','him',"i've",'on', 'her','told','ins', '1 check','I', 'i"m', 'i', ' ', 'it', "it's", 'it.','they', 'the', 'this','its', 'l','they','this',"don't",'the ', ' the', 'it', 'i"ve', 'i"m', '!', '1','2','3','4', '5','6','7','8','9','0','/','.',',']

# stopwords = [',','"','!','-','&','?','was']

def filter_stopwords(text):
  nonstopwords = []
  for i in text:
    if i not in stopwords:
      nonstopwords.append(i)
  return nonstopwords
df['tokenized_text'] = df['tokenized_text'].apply(filter_stopwords)
df['parts_of_speech_reference'] = df['tokenized_text'].apply(filter_stopwords)
df['parts_of_speech_reference'] = df['parts_of_speech_reference'].str.join(' ')

def find_noun_noun(x):
  noun_list = []
  doc = nlp(str(x))
  try:
    for token in range(len(doc)):
      sub_list = []
      if doc[token].pos_ == 'NOUN'and doc[token+1].pos_ == 'NOUN':
        sub_list.append(doc[token-1])
        sub_list.append(doc[token])
        sub_list.append(doc[token+1])
      if len(sub_list) != 0 and sub_list not in noun_list:
        noun_list.append(sub_list)
  except IndexError as e:
    pass
  return noun_list

def find_adj_noun(x):
  adj_noun_list = []
  doc = nlp(str(x))
  try:
    for token in range(len(doc)):
      sub_list = []
      if doc[token].pos_ == 'ADJ'and doc[token+1].pos_ == 'NOUN':
        sub_list.append(doc[token-1])
        sub_list.append(doc[token])
        sub_list.append(doc[token+2])
      if len(sub_list) != 0 and sub_list not in adj_noun_list:
        adj_noun_list.append(sub_list)
  except IndexError as e:
    pass
  return adj_noun_list

def find_the(x):
  the_list = []
  doc = nlp(str(x))
  try:
    for token in range(len(doc)):
      sub_list = []
      if doc[token].text == 'the' or doc[token].text == 'a' or doc[token].text == 'an':
        sub_list.append(doc[token+1])
        sub_list.append(doc[token+2])
        sub_list.append(doc[token+3])
        # sub_list.append(doc[token+4])
      if len(sub_list) != 0 and sub_list not in the_list:
        the_list.append(sub_list)
  except IndexError as e:
    pass
  return the_list

df['word_segments_nn'] = df['parts_of_speech_reference'].apply(find_noun_noun)
df['word_segments_adjn'] = df['parts_of_speech_reference'].apply(find_adj_noun)
df['word_segments_the'] = df['parts_of_speech_reference'].apply(find_the)

noun_noun_phrases = []
for i in df['word_segments_nn']:
  for x in i:
    string = ' '.join([str(elem) for elem in x]) 
    noun_noun_phrases.append(string)
adj_noun_phrases = []
for i in df['word_segments_adjn']:
  for x in i:
    string = ' '.join([str(elem) for elem in x]) 
    adj_noun_phrases.append(string)
the_phrases = []
for i in df['word_segments_the']:
  for x in i:
    string = ' '.join([str(elem) for elem in x]) 
    the_phrases.append(string)

all_phrases = noun_noun_phrases + adj_noun_phrases + the_phrases
print(all_phrases)
# Out:
# ['high quality spot', 'fresh creole flavor', 'spicy tomato jam', 'tomato jam lightens', 'with jazz music', 'Clientele divers friends', 'doing lunch couples', 'lunch couples vacation', 'couples vacation couples', 'up lunch break', 'lunch break individuals', 'favorite stand bys', 'visual appeal flavor', 'ordered beignet flight', 'fried chicken bene', 'chicken bene pork', 'bene pork belly', 'Soul Food OWES', 'Food OWES ME', 'OWES ME NOTHING', 'new orleans style', 'your name number', 'down chalk board', 'small seating area', 'lol Love food', 'southern soul food', 'soul food ambiance', 'food ambiance lol', 'brunch chaser crowd', 'hot links breakfast', 'my eye stomach', 'BTC chicken breast', 'chicken breast side', 'breast side sooo', 'Tried shrimp poboy', 'Top notch spices', 'off hook good', 'plus size love', 'size love space', 'juicy tender chicken', 'a watermelon tea', 'other items menu', 'your table neighbor', 'a guava mimosa', 'grits beignet sampler', 'chose beignet sampler', 'The staff attentive', 'my friends family', 'with jam butter', 'during weekend brunch', 'But food soooo', 'food soooo good', 'fried catfish eggs', 'mostly street parking', 'give place anything', 'between breakfast dinner', 'Crawfish beignets gumbo', 'Yummm yummm yummm', 'for beignet flight', 'a cafe mocha', 'melted cheese spices', 'my taste buds', 'but chicken jamabalya', 'chicken jamabalya catfish', 'jamabalya catfish gumbo', 'with strawberry jam', 'there pepper jelly', 'homeless people streets', 'for breakfast brunch', 'give place stars', 'of spice shrimp', 'a work trip', 'Friendly customer service', 'a bit persnickety', 'a breakfast sandwich', 'scrambled egg chicken', 'egg chicken sausage', 'chicken sausage cheddar', 'sausage cheddar cheese', 'an orange juice', 'ordered watermelon tea', 'three way beignets', 'brisket seafood pasta', 'Service umm time', 'umm time frame', 'time frame seriving', 'frame seriving times', 'off dinner menu', 'great breakfast place', 'breakfast place Lots', 'of atmosphere kind', 'entire menu spoiler', 'pickled watermelon rind', 'most lunch dishes', 'a breakfast dish', 'smoked tomato grits', 'from tomato juicy', 'tomato juicy mean', 'Their cream biscuits', 'strawberry jam table', 'Delicious chicory coffee', 'very chill vibe', 'a coffee drink', 'French toast spinach', 'authentic soul food', 'fried corn bread', 'waitress food servers', 'po boy beignets', 'atmosphere Cheese grits', 'in years restaurant', 'Tried watermelon tea', 'special creole shrimp', 'creole shrimp pot', 'shrimp pot pie', 'decent creole beignet', 'that bar bartender', 'pulled pork sammich', 'Our server rude', 'ordered hangtown fry', 'hangtown fry oysters', 'of food hygiene', 'your money waste', 'better review catfish', 'smoked chicken etoufee', 'gumbo yams chicken', 'yams chicken shrimp', 'chicken shrimp pot', 'shrimp pot pie', 'pot pie shrimp', 'pie shrimp salad', 'shrimp salad cheese', 'salad cheese grits', 'try beignets brunch', 'Creole soul food', 'soul food restaurant', 'googled soul food', 'great service food', 'all flavors seasonings', 'The restaurant quaint', 'restaurant quaint cute', 'of sausage chicken', 'Flavor crispy point', 'crispy point Portions', 'point Portions plenty', 'a peach cobbler', 'peach cobbler ala', 'cobbler ala mode', "'s food ambiance", 'with hash cream', 'hash cream biscuit', 'my drink watermelon', 'in grade school', 'in hangtown fry', 'never food poisoning', 'kill virulent pathogens', 'ever shrimp grits', 'sweet savory tomatoes', 'at home wish', 'NOLA gastro scene', 'to gas station', 'gas station diners', 'in bumpkin towns', "'s souls food", 'red beans rice', 'My wife son', 'a couple times', 'My wife year', 'saw crack pipes', 'of smugness cause', 'but beignet dough', 'a breakfast thing', 'a bucket list', 'Sunday brunch table', 'ordered beignet flight', 'fried shrimp eggs', 'Beignet flight crispy', 'flight crispy pork', 'crispy pork belly', 'as hang town', 'The grits beignet', 'Service food exceptional', 'Great customer service', 'food ...

# %%
class FlashTextExtact(st.FeatsFromSpacyDoc):
    '''
    '''
    def set_keyword_processor(self, keyword_processor):
        '''
        :param keyword_processor: set, phrases to look for
        :return: self
        '''
        self.keyword_processor_ = keyword_processor
        return self

    def get_feats(self, doc):
        '''
        Parameters
        ----------
        doc, Spacy Doc
        Returns
        -------
        Counter noun chunk -> count
        '''
        return Counter(self.keyword_processor_.extract_keywords(str(doc)))

# %%
df.head(1)
# Out:
#                            0  \
# 0  \n        10/9/2019\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        1  \
# 0  Looking for a unique, high quality spot in San Fran for a great bite to eat, this is it! We found it looking on Yelp and were not disappointed one bit. Unfortunately located with the surrounding decline of SF but a hidden gem for great service and fantastic food. The seafood was fresh and the creole flavor is true. The grits are some of the best I have ever had, the spicy tomato jam lightens the typically heavy dish. We will be back!
#
#                  2  \
# 0  5.0 star rating
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                         tokenized_text  \
# 0  [Looking, for, a, unique, high, quality, spot, in, San, Fran, for, a, great, bite, to, eat, is, We, found, looking, Yelp, not, disappointed, one, bit, Unfortunately, located, with, surrounding, decline, of, SF, but, a, hidden, gem, for, great, service, fantastic, food, The, seafood, fresh, creole, flavor, is, true, The, grits, are, some, of, best, have, ever, spicy, tomato, jam, lightens, typically, heavy, dish, We, will, be, back]
#
#                                                                                                                                                                                                                                                                                                                                                          parts_of_speech_reference  \
# 0  Looking for a unique high quality spot in San Fran for a great bite to eat is We found looking Yelp not disappointed one bit Unfortunately located with surrounding decline of SF but a hidden gem for great service fantastic food The seafood fresh creole flavor is true The grits are some of best have ever spicy tomato jam lightens typically heavy dish We will be back
#
#                                                                                   word_segments_nn  \
# 0  [[high, quality, spot], [fresh, creole, flavor], [spicy, tomato, jam], [tomato, jam, lightens]]
#
#                                                                                                                                                                    word_segments_adjn  \
# 0  [[unique, high, spot], [a, great, to], [a, hidden, for], [for, great, fantastic], [service, fantastic, The], [seafood, fresh, flavor], [ever, spicy, jam], [typically, heavy, We]]
#
#                                                   word_segments_the  \
# 0  [[unique, high, quality], [great, bite, to], [hidden, gem, for]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          parse
# 0  (looking, for, a, unique, ,, high, quality, spot, in, san, fran, for, a, great, bite, to, eat, ,, this, is, it, !, we, found, it, looking, on, yelp, and, were, not, disappointed, one, bit, ., unfortunately, located, with, the, surrounding, decline, of, sf, but, a, hidden, gem, for, great, service, and, fantastic, food, ., the, seafood, was, fresh, and, the, creole, flavor, is, true, ., the, grits, are, some, of, the, best, i, have, ever, had, ,, the, spicy, tomato, jam, lightens, the, typically, heavy, dish, ., we, will, be, back, !)

# %%
keyword_processor = KeywordProcessor(case_sensitive=False)

for phrase in all_phrases:
    keyword_processor.add_keyword(phrase)
feature_extractor = FlashTextExtact().set_keyword_processor(keyword_processor)

df['parse'] = df['parts_of_speech_reference'].apply(st.whitespace_nlp_with_sentences)
corpus = (st.CorpusFromPandas(df,
                              category_col=2,
                              text_col='parts_of_speech_reference',
                              nlp=st.whitespace_nlp_with_sentences,
                              feats_from_spacy_doc=feature_extractor)
          .build())

# print(corpus.get_term_freq_df())

term_freq_df = corpus.get_term_freq_df()
term_freq_df['highratingscore'] = corpus.get_scaled_f_scores('5.0 star rating')

term_freq_df['poorratingscore'] = corpus.get_scaled_f_scores('1.0 star rating')
dh = term_freq_df.sort_values(by= 'highratingscore', ascending = False)
dh = dh[['highratingscore', 'poorratingscore']]
dh = dh.reset_index(drop=False)
dh = dh.rename(columns={'highratingscore': 'score'})
dh = dh.drop(columns='poorratingscore')
# positive_df = dh.head(10)
# negative_df = dh.tail(10)

# html = st.produce_scattertext_explorer(
#     corpus,
#     category='democrat',
#     category_name='Democratic',
#     not_category_name='Republican',
#     metadata=convention_df['speaker'],
#     term_scorer=st.RankDifference(),
#     transform=st.Scalers.dense_rank,
#     pmi_threshold_coefficient=0,
#     minimum_term_frequency=0,
#     minimum_not_category_term_frequency=0,
#     use_full_doc=True
# )

# file_name = 'demo_specific_phrases.html'
# open(file_name, 'wb').write(html.encode('utf-8'))
# print('Open %s in Chrome or Firefox.' % file_name)

# %%
dh
# Out:
#                               term     score
# 0                    line out door  1.000000
# 1              watermelon iced tea  1.000000
# 2              review because just  1.000000
# 3                     cup of gumbo  1.000000
# 4                   but food soooo  1.000000
# 5               Great service food  1.000000
# 6               fried chicken eggs  0.923501
# 7           fried chicken benedict  0.923501
# 8                 French soul food  0.823535
# 9                      line to get  0.805222
# 10                  great place to  0.805222
# 11          Ordered beignet flight  0.760069
# 12             exquisite soul food  0.500000
# 13                  gem Small tiny  0.500000
# 14                        bit of a  0.500000
# 15                very fancy place  0.500000
# 16               in line recommend  0.500000
# 17           blustery overcast day  0.500000
# 18             favorite lunch spot  0.500000
# 19            toffee chip pancakes  0.500000
# 20                 little long but  0.500000
# 21         excellent food biscuits  0.500000
# 22              long line weekends  0.500000
# 23        delicious breakfast here  0.500000
# 24                    in west cost  0.500000
# 25                    must if your  0.500000
# 26                  wait but never  0.500000
# 27             unique high quality  0.500000
# 28   traditional breakfast choices  0.500000
# 29                with shrimp goat  0.500000
# 30                   group or even  0.500000
# 31                has comfort food  0.500000
# 32                    oh man place  0.500000
# 33                  favor eat here  0.500000
# 34          loved decor atmosphere  0.500000
# 35        southern biscuit instead  0.500000
# 36         fantastic coffee delish  0.500000
# 37                a couple seating  0.500000
# 38              three egg omelette  0.500000
# 39              loop but delicious  0.500000
# 40     fantastic brunch experience  0.500000
# 41              loved shrimp grits  0.500000
# 42          fresh watermelon juice  0.500000
# 43                    side of hash  0.500000
# 44           perfectly poached egg  0.500000
# 45               fried chicken top  0.500000
# 46                  very long line  0.500000
# 47               Tuesday around 11  0.500000
# 48            always fried chicken  0.500000
# 49                     hour to eat  0.500000
# 50                  at coffee shop  0.500000
# 51             a chicken drumstick  0.500000
# 52        Service food exceptional  0.500000
# 53               The grits beignet  0.500000
# 54                    as hang town  0.500000
# 55                  poached egg as  0.500000
# 56                   a bucket list  0.500000
# 57                shell of beignet  0.500000
# 58               a breakfast thing  0.500000
# 59               but beignet dough  0.500000
# 60         very interesting flavor  0.500000
# 61               hit with everyone  0.500000
# 62                     tiny bit of  0.500000
# 63                hour later there  0.500000
# 64             few tables occupied  0.500000
# 65   inappropriate conversation as  0.500000
# 66                fairly small but  0.500000
# 67                  red beans rice  0.500000
# 68                    at home wish  0.500000
# 69          Great customer service  0.500000
# 70                   good ass soul  0.500000
# 71                   wait You used  0.500000
# 72            little donuts flight  0.500000
# 73          Tuesday morning waited  0.500000
# 74        chipotle remoulade cream  0.500000
# 75              tried guava mimosa  0.500000
# 76             faster than average  0.500000
# 77                   great bite to  0.500000
# 78      andouille sausage omelette  0.500000
# 79                Saturday did not  0.500000
# 80               bonus when server  0.500000
# 81           worth Everything menu  0.500000
# 82                   long ass line  0.500000
# 83                lot tastier than  0.500000
# 84        beautiful drizzly Sunday  0.500000
# 85              romantic amd music  0.500000
# 86                 of egg benedict  0.500000
# 87                 few blocks down  0.500000
# 88                    good time to  0.500000
# 89                   few years ago  0.500000
# 90             other order beignet  0.500000
# 91             fried chicken fries  0.500000
# 92                what craving hit  0.500000
# 93                 entree ended up  0.500000
# 94             favorite dish Fried  0.500000
# 95                  a waiting list  0.500000
# 96     creole flavored hollandaise  0.500000
# 97                   table for The  0.500000
# 98                      hour for a  0.500000
# 99                   Sunday at 1PM  0.500000
# 100          BBQ shrimp appetizers  0.500000
# 101         ordering oyster flight  0.500000
# 102                 over yelp page  0.500000
# 103          Biscuits cheese grits  0.500000
# 104          party of Surprisingly  0.500000
# 105              Friday night with  0.500000
# 106                    must try SF  0.500000
# 107               have 10k reviews  0.500000
# 108                 The gumbo good  0.500000
# 109                loves apple pie  0.500000
# 110       Monday afternoon luckily  0.500000
# 111      highly recommend beignets  0.500000
# 112             must Everything is  0.500000
# 113                a specials menu  0.500000
# 114              ever shrimp grits  0.500000
# 115                decent size for  0.500000
# 116         beignets hash potatoes  0.500000
# 117                great food talk  0.500000
# 118              empty plate table  0.500000
# 119                  woman by name  0.500000
# 120             taste of Louisiana  0.500000
# 121    a disappointment Everything  0.500000
# 122                    lot of good  0.500000
# 123          careful inhale powder  0.500000
# 124            location in Oakland  0.500000
# 125                   side as well  0.500000
# 126                 whole order So  0.500000
# 127             regular omelet The  0.500000
# 128                my husband corn  0.500000
# 129                   bit cozy but  0.500000
# 130          Sunday morning around  0.500000
# 131              both moist crispy  0.500000
# 132          iconic creole cuisine  0.500000
# 133       Southern restaurant that  0.500000
# 134               The host servers  0.500000
# 135                limited menu at  0.500000
# 136           between lunch dinner  0.500000
# 137               single older guy  0.500000
# 138                   musty try It  0.500000
# 139         Friday early afternoon  0.500000
# 140                 little over 20  0.500000
# 141            weekday if possible  0.500000
# 142                heavy amount of  0.500000
# 143           ridiculous amount of  0.500000
# 144                  taste for yet  0.500000
# 145                  few soul food  0.500000
# 146                 very messy but  0.500000
# 147                enjoy soul food  0.500000
# 148                   space for me  0.500000
# 149               The host hostess  0.500000
# 150               catch bus corner  0.500000
# 151             early dinner going  0.500000
# 152                     MUST in SF  0.500000
# 153            soft beignets apple  0.500000
# 154               of beignets love  0.500000
# 155            fried chicken sauce  0.500000
# 156                ideal place for  0.500000
# 157                their soul food  0.500000
# 158                couple of cafes  0.500000
# 159                few Crawfish is  0.500000
# 160                 rainy day Will  0.500000
# 161                  umbrella if a  0.500000
# 162             friend over brunch  0.500000
# 163                  mimosa with a  0.500000
# 164                  great spot to  0.500000
# 165         brought friends family  0.500000
# 166        with creole hollandaise  0.500000
# 167          good selection shrimp  0.500000
# 168                  a matinee red  0.500000
# 169               a friday morning  0.500000
# 170                a pancakes kind  0.500000
# 171  adventurous person especially  0.500000
# 172               few minutes wait  0.500000
# 173                late ish dinner  0.500000
# 174              SF breakfast spot  0.500000
# 175                true hidden gem  0.500000
# 176          This breakfast brunch  0.500000
# 177          sweet savory tomatoes  0.500000
# 178           favorite brunch spot  0.500000
# 179                of spice shrimp  0.500000
# 180                  lot of people  0.500000
# 181                 a coffee drink  0.500000
# 182             beverage ordered a  0.500000
# 183           melted cheese spices  0.500000
# 184     real watermelon Definitely  0.500000
# 185                 try some other  0.500000
# 186         appointment greeted by  0.500000
# 187                 good amount of  0.500000
# 188       Delicious chicory coffee  0.500000
# 189                drink less than  0.500000
# 190                 meal with your  0.500000
# 191           abundance of amazing  0.500000
# 192                 a guava mimosa  0.500000
# 193          grits beignet sampler  0.500000
# 194          chose beignet sampler  0.500000
# 195           strawberry jam table  0.500000
# 196           Their cream biscuits  0.500000
# 197           French toast spinach  0.500000
# 198            authentic soul food  0.500000
# 199           juicy tender chicken  0.500000
# 200                 plus size love  0.500000
# 201            Thursday there only  0.500000
# 202                 short wait got  0.500000
# 203             BTC chicken breast  0.500000
# 204             Tried shrimp poboy  0.500000
# 205                     drink at a  0.500000
# 206          extremely large group  0.500000
# 207                    trip to New  0.500000
# 208            spicy mayonise also  0.500000
# 209            hot sauce depending  0.500000
# 210               Top notch spices  0.500000
# 211                  off hook good  0.500000
# 212            in years restaurant  0.500000
# 213                po boy beignets  0.500000
# 214               major birthday I  0.500000
# 215              little kick would  0.500000
# 216              from tomato juicy  0.500000
# 217            smoked tomato grits  0.500000
# 218              super sweet extra  0.500000
# 219            give place anything  0.500000
# 220        Crawfish beignets gumbo  0.500000
# 221              Yummm yummm yummm  0.500000
# 222                   friend so we  0.500000
# 223               try From outside  0.500000
# 224                simple cafe but  0.500000
# 225      considerable line outside  0.500000
# 226            chalkboard We ended  0.500000
# 227            with strawberry jam  0.500000
# 228                   hour just to  0.500000
# 229                  spot but well  0.500000
# 230                    must try in  0.500000
# 231                  my taste buds  0.500000
# 232          order Everything menu  0.500000
# 233             for beignet flight  0.500000
# 234                   a cafe mocha  0.500000
# 235             there pepper jelly  0.500000
# 236               give place stars  0.500000
# 237         additional little side  0.500000
# 238                  great meal is  0.500000
# 239               a breakfast dish  0.500000
# 240              most lunch dishes  0.500000
# 241        pickled watermelon rind  0.500000
# 242                  side of their  0.500000
# 243            entire menu spoiler  0.500000
# 244               decade now never  0.500000
# 245             of atmosphere kind  0.500000
# 246          great breakfast place  0.500000
# 247          brisket seafood pasta  0.500000
# 248                great time here  0.500000
# 249                   meal did not  0.500000
# 250            The staff attentive  0.500000
# 251              my friends family  0.500000
# 252             fried catfish eggs  0.500000
# 253          mostly street parking  0.500000
# 254                 local dive bar  0.500000
# 255           watermelon tea which  0.500000
# 256             fried chicken bene  0.500000
# 257             favorite stand bys  0.500000
# 258              new orleans style  0.500000
# 259                 shrimp pot pie  0.500000
# 260               Creole soul food  0.500000
# 261             fluke just googled  0.500000
# 262         all flavors seasonings  0.500000
# 263          The restaurant quaint  0.500000
# 264             of sausage chicken  0.500000
# 265                OWES ME NOTHING  0.500000
# 266             that bar bartender  0.500000
# 267                 little over an  0.500000
# 268               very nice visual  0.500000
# 269          perfect complement to  0.500000
# 270                 up lunch break  0.500000
# 271             southern soul food  0.500000
# 272            Flavor crispy point  0.500000
# 273                a peach cobbler  0.500000
# 274            doing lunch couples  0.500000
# 275                minute for your  0.500000
# 276       Clientele divers friends  0.500000
# 277                with jazz music  0.500000
# 278         Wednesday walked right  0.500000
# 279               spicy tomato jam  0.500000
# 280            fresh creole flavor  0.500000
# 281                 hidden gem for  0.500000
# 282                 chance with us  0.500000
# 283               order of beignet  0.500000
# 284                  bit humid hot  0.500000
# 285       flavored gravy perfectly  0.500000
# 286            brunch chaser crowd  0.289988
# 287          during weekend brunch  0.289988
# 288              Our soul purposes  0.289988
# 289            less than satisfied  0.289988
# 290             of reviews beignet  0.289988
# 291        Saturday morning really  0.289988
# 292                   long wait 45  0.289988
# 293                    good way to  0.289988
# 294              city that thrives  0.289988
# 295           their friends family  0.289988
# 296            Friday afternoon PM  0.289988
# 297            solid believe place  0.289988
# 298                  for soul food  0.289988
# 299              The vibe ambiance  0.289988
# 300                     hour to an  0.289988
# 301                    hour a half  0.289988
# 302                    huge fan of  0.289988
# 303           It soooooooooo tasty  0.289988
# 304         frequent customer when  0.289988
# 305               my beignet phase  0.289988
# 306                  a minute walk  0.289988
# 307          there staff attentive  0.289988
# 308         crawfish apple Nutella  0.289988
# 309            with potatoes cream  0.289988
# 310                    must go for  0.289988
# 311            Our hotel concierge  0.289988
# 312               down street food  0.289988
# 313                while to figure  0.289988
# 314           restaurant but great  0.289988
# 315                a weekend thing  0.289988
# 316         with beignet appetizer  0.289988
# 317               thought hell yea  0.289988
# 318            seminar nearby when  0.289988
# 319                  waste of time  0.289988
# 320                 my eye stomach  0.289988
# 321               really long time  0.289988
# 322           ordered cream cheese  0.289988
# 323               espresso to boot  0.289988
# 324            excessive amount of  0.289988
# 325             a refund overheard  0.289988
# 326      terrible customer service  0.289988
# 327            hot links breakfast  0.289988
# 328              try Beignets came  0.289988
# 329               smaller Menu but  0.289988
# 330                 got rice beans  0.289988
# 331       between breakfast dinner  0.289988
# 332                  a poboy apple  0.289988
# 333          no flavour everything  0.289988
# 334                 while back for  0.289988
# 335                  grain of salt  0.289988
# 336              bit during brunch  0.289988
# 337              our dinner orders  0.289988
# 338                  Oyster po boy  0.289988
# 339                for goat cheese  0.289988
# 340          perfect bread crunchy  0.289988
# 341               black woman felt  0.289988
# 342                 The food bland  0.289988
# 343             fried oysters kids  0.289988
# 344        fried chicken something  0.289988
# 345                Calif chef need  0.289988
# 346         delicious shrimp grits  0.289988
# 347               great value love  0.289988
# 348             posted house rules  0.289988
# 349           favorite bless heart  0.289988
# 350                 that soul food  0.289988
# 351                rated soul food  0.289988
# 352               a liquor license  0.289988
# 353                chance to check  0.289988
# 354               your name number  0.289988
# 355               down chalk board  0.289988
# 356                hour luckily we  0.289988
# 357             small seating area  0.289988
# 358               of mystery sauce  0.289988
# 359               dry shrimp grits  0.289988
# 360                variety of menu  0.289988
# 361            quick dinner before  0.289988
# 362                with jam butter  0.289988
# 363                fan of biscuits  0.289988
# 364    because restaurant ambiance  0.289988
# 365                little tough to  0.289988
# 366        very popular restaurant  0.289988
# 367                   favor to let  0.289988
# 368         solid customer service  0.289988
# 369                  long line The  0.289988
# 370            Sunday morning just  0.289988
# 371              SH school meeting  0.289988
# 372           their watermelon ice  0.289988
# 373              their house rules  0.289988
# 374                  a chalk board  0.289988
# 375         got succotash omelette  0.289988
# 376              to school parking  0.289988
# 377             off putting policy  0.289988
# 378              good stuff server  0.289988
# 379                    of day food  0.289988
# 380             low rating because  0.289988
# 381                 from soul food  0.289988
# 382                 hard pass from  0.289988
# 383            my drink watermelon  0.289988
# 384                    pair of bar  0.289988
# 385               biscuit that has  0.289988
# 386           omelette filled with  0.289988
# 387                   to hour half  0.289988
# 388            pulled pork sammich  0.289988
# 389                      bit for a  0.289988
# 390                  table but you  0.289988
# 391                Our server rude  0.289988
# 392              your bullshit way  0.289988
# 393              a oyster scallion  0.289988
# 394            great unique brunch  0.289988
# 395                few hours later  0.289988
# 396           ordered hangtown fry  0.289988
# 397              little off should  0.289988
# 398                of food hygiene  0.289988
# 399               your money waste  0.289988
# 400         slightly cramped space  0.289988
# 401                 hour take your  0.289988
# 402                 few months ago  0.289988
# 403            a weekend afternoon  0.289988
# 404          busy Saturday evening  0.289988
# 405               little too dense  0.289988
# 406                      of a star  0.289988
# 407          waitress food servers  0.289988
# 408                bit more flavor  0.289988
# 409                  whole meal if  0.289988
# 410           Tried watermelon tea  0.289988
# 411          special creole shrimp  0.289988
# 412          decent creole beignet  0.289988
# 413          The chocolate beignet  0.289988
# 414             got beignet flight  0.289988
# 415         great southern cooking  0.289988
# 416                   bit tight as  0.289988
# 417          The sauce spectacular  0.289988
# 418                    fish po boy  0.289988
# 419           southern cuisine fix  0.289988
# 420              Saturday night We  0.289988
# 421                fried fish eggs  0.289988
# 422          better review catfish  0.289988
# 423              sparkling rose My  0.289988
# 424          reservation if accept  0.289988
# 425                 to gas station  0.289988
# 426        sketchy neighborhood We  0.289988
# 427                    My wife son  0.289988
# 428           side truthfully that  0.289988
# 429         big disappointment due  0.289988
# 430           serious craving like  0.289988
# 431            serious craving for  0.289988
# 432               in bumpkin towns  0.289988
# 433              NOLA gastro scene  0.289988
# 434                 good brunch in  0.289988
# 435                   dime a dozen  0.289988
# 436                with hash cream  0.289988
# 437        kill virulent pathogens  0.289988
# 438           never food poisoning  0.289988
# 439                in hangtown fry  0.289988
# 440                in grade school  0.289988
# 441                large volume of  0.289988
# 442                    lady with a  0.289988
# 443        another homeless person  0.289988
# 444                  lady said kid  0.289988
# 445                 a couple times  0.289988
# 446             problem with would  0.289988
# 447              really busy place  0.289988
# 448             couple of biscuits  0.289988
# 449              fried shrimp eggs  0.289988
# 450                 bunch of other  0.289988
# 451                    hour with a  0.289988
# 452            Sunday brunch table  0.289988
# 453         smoked chicken etoufee  0.289988
# 454             gumbo yams chicken  0.289988
# 455            shrimp salad cheese  0.289988
# 456            try beignets brunch  0.289988
# 457                   Uber back to  0.289988
# 458           scary situation just  0.289988
# 459                saw crack pipes  0.289988
# 460                   My wife year  0.289988
# 461                wow factor feel  0.289988
# 462               fried corn bread  0.289988
# 463              cold morning just  0.289988
# 464             a chance yesterday  0.289988
# 465             for watermelon ice  0.289988
# 466                 is death knell  0.289988
# 467               Cajun food bland  0.289988
# 468               very sketchy kfc  0.289988
# 469              get yelp waitlist  0.289988
# 470              lot in tenderloin  0.289988
# 471                  hour to order  0.289988
# 472              000 reviews stars  0.289988
# 473      Friendly customer service  0.289988
# 474         joke Terrible waitress  0.289988
# 475              Orleans soul food  0.289988
# 476                 any egg batter  0.289988
# 477             regular brand like  0.289988
# 478         Wednesday seated right  0.289988
# 479               side of coleslaw  0.289988
# 480           fried chicken shrimp  0.289988
# 481              a bit persnickety  0.289988
# 482       weekday Crawfish Beignet  0.289988
# 483              My friend stomach  0.289988
# 484          delicious biscuit jam  0.289988
# 485             group of coworkers  0.289988
# 486                  third time We  0.289988
# 487          but chicken jamabalya  0.289988
# 488                much bigger fan  0.289988
# 489          Brunch menu something  0.289988
# 490                super kind game  0.289988
# 491      phenomenal watermelon tea  0.289988
# 492              for grits shrimps  0.289988
# 493                bit longer than  0.289988
# 494                   bit too much  0.289988
# 495             fried chicken good  0.289988
# 496            Great size portions  0.289988
# 497        homeless people streets  0.289988
# 498           for breakfast brunch  0.289988
# 499             hour later started  0.289988
# 500                    a work trip  0.289988
# 501            Had sampler oysters  0.289988
# 502           a breakfast sandwich  0.289988
# 503                off dinner menu  0.289988
# 504                 new meal Since  0.289988
# 505  popular breakfast restaurants  0.289988
# 506                 spot so pretty  0.289988
# 507                 Saturday we to  0.289988
# 508                    pool of oil  0.289988
# 509                 bit too greasy  0.289988
# 510                    go The food  0.289988
# 511              Saturday Hot take  0.289988
# 512                     hair in my  0.289988
# 513               a sausage omelet  0.289988
# 514              a weekday Service  0.289988
# 515                 show at Curran  0.289988
# 516              quick meal before  0.289988
# 517                very chill vibe  0.289988
# 518                  pm a Saturday  0.289988
# 519               No frills brunch  0.289988
# 520         Good breakfast service  0.289988
# 521              Ordered craw fish  0.289988
# 522                  while This is  0.289988
# 523          scrambled egg chicken  0.289988
# 524           frame seriving times  0.289988
# 525         sausage cheddar cheese  0.289988
# 526               semi fed stomach  0.289988
# 527                  lot easier to  0.289988
# 528                  cup of coffee  0.289988
# 529                 The pork belly  0.289988
# 530             shrimp goat cheese  0.289988
# 531                Saturday We got  0.289988
# 532         numerous times nothing  0.289988
# 533          rude customer service  0.289988
# 534                an orange juice  0.289988
# 535                  small cup not  0.289988
# 536         ordered watermelon tea  0.289988
# 537             three way beignets  0.289988
# 538                   lot of water  0.289988
# 539               Service umm time  0.289988
# 540              crispy pork belly  0.144164
# 541                crazy long line  0.000000

# %%
positive_df = dh.head(10)
negative_df = dh.tail(10)


results = {'positive': [{'term': pos_term, 'score': pos_score} for pos_term, pos_score in
                        zip(positive_df['term'], positive_df['score'])],
            'negative': [{'term': neg_term, 'score': neg_score} for neg_term, neg_score in
                        zip(negative_df['term'], negative_df['score'])]}

# %%
results
# Out:
# {'negative': [{'score': 0.28998794732248623, 'term': 'numerous times nothing'},
#   {'score': 0.28998794732248623, 'term': 'rude customer service'},
#   {'score': 0.28998794732248623, 'term': 'an orange juice'},
#   {'score': 0.28998794732248623, 'term': 'small cup not'},
#   {'score': 0.28998794732248623, 'term': 'ordered watermelon tea'},
#   {'score': 0.28998794732248623, 'term': 'three way beignets'},
#   {'score': 0.28998794732248623, 'term': 'lot of water'},
#   {'score': 0.28998794732248623, 'term': 'Service umm time'},
#   {'score': 0.14416388105176076, 'term': 'crispy pork belly'},
#   {'score': 0.0, 'term': 'crazy long line'}],
#  'positive': [{'score': 1.0, 'term': 'line out door'},
#   {'score': 1.0, 'term': 'watermelon iced tea'},
#   {'score': 1.0, 'term': 'review because just'},
#   {'score': 1.0, 'term': 'cup of gumbo'},
#   {'score': 1.0, 'term': 'but food soooo'},
#   {'score': 1.0, 'term': 'Great service food'},
#   {'score': 0.9235014647642518, 'term': 'fried chicken eggs'},
#   {'score': 0.9235014647642518, 'term': 'fried chicken benedict'},
#   {'score': 0.8235349315267401, 'term': 'French soul food'},
#   {'score': 0.8052219896491868, 'term': 'line to get'}]}
